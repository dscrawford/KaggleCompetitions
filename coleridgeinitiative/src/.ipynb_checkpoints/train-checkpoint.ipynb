# %% [markdown]
# ***First Proposed Idea***
#
# Create a RNN that predicts at the sentence level whether there is a dataset or not.

# %%
import torch
import json
import os
import pandas as pd
import numpy as np
import nltk
import re

# %%
from nltk.corpus import stopwords, words
from collections import defaultdict

# %%
WORD_DIM = 100
STOP_WORDS = list() # stopwords.words('english')
WD = "../"
TRAIN_DIR = WD + "train/"
TEST_DIR  = WD + "test/"

# %%
class CorpusPipeline:
    """
    A class to transform a corpus into a list of features.
    
    ...
    
    Attributes
    ----------
    word_dim : int
        number of words to be held in a fixed size array
    stop_words : list
        list of stop words to omit from sentence
    """
    
    def __init__(self, word_dim, stop_words):
        self.word_dim = word_dim
        self.stop_words = set(stop_words)
        self.word_dict = defaultdict(lambda: 0)

    def clean_text(self, txt):
        """Return cleaned text according to regex"""
        return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower())
    
    def remove_stop_words(self, word_arr):
        """Return a word array without stop words"""
        return [word for word in word_arr if word not in self.stop_words]
    
    def fit(self, corpora):
        """Creates a word to int dictionary from a corpora"""
        
        # Create word to int dictionary
        full_text = ' '.join(corpora)
        words = nltk.word_tokenize(self.clean_text(full_text))
        i = 1
        for word in set(words):
            self.word_dict[word] = i
            i += 1
        
    
    def get_features_labels(self, corpus: str, labels: list):
        """Return a corpus represented as a list of features"""
        x = nltk.sent_tokenize(corpus)
        features = np.zeros(self.word_dim)
        labels   = np.zeros(self.word_dim)
        
        x = self.clean_text(corpus)
        x = nltk.word_tokenize(x)
        x = self.remove_stop_words(x)
#         x = [self.word_dict[word] for word in x]

        y = self.clean_text()
        
        features[0:min(len(x), self.word_dim)] = x[0:min(len(x), self.word_dim)]
        
        return features
    
    def transform(self, df, text_column, feature_column_name='features'):
        return df[text_column].apply(lambda x: self.get_features(x))

# %%
a = ['hello', 'my', 'name', 'is', 'daniel']
b = ['my', 'name', 'is']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-bdb7c2d0d694> in <module>
#       1 a = ['hello', 'my', 'name', 'is', 'daniel']
#       2 b = ['my', 'name', 'is']
# ----> 3 b.to_str()
#
# AttributeError: 'list' object has no attribute 'to_str'

# %%
def load_data(path):
    """Iterate through every file in a path and transform into a dataframe with notebook id, section title and text"""
    ids = os.listdir(path)
    return [[ID[0:-5]] + [i[1] for i in section.items()] for ID in ids for section in json.load(open(path + '/' + ID))]

# %%
train_data   = pd.DataFrame(load_data(TRAIN_DIR), columns=['Id', 'section_title', 'text']).astype(str)
train_labels = pd.read_csv('../train.csv').astype(str)

# %%
train_data
# Out:
#                                           Id  \
# 0       178d9a89-ca76-456d-bf9e-5b80eaae2d49
# 1       178d9a89-ca76-456d-bf9e-5b80eaae2d49
# 2       178d9a89-ca76-456d-bf9e-5b80eaae2d49
# 3       178d9a89-ca76-456d-bf9e-5b80eaae2d49
# 4       178d9a89-ca76-456d-bf9e-5b80eaae2d49
# ...                                      ...
# 258709  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 258710  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 258711  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 258712  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 258713  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
#
#                                             section_title  \
# 0                                            Introduction
# 1                      2017). J. Educ. Sci Environ Health
# 2       The Primary Stages Followed in Scale Adaptatio...
# 3                     Confirmatory Factor Analysis (CFA):
# 4                         The Studies Conducted in Turkey
# ...                                                   ...
# 258709                                            Results
# 258710    The Alzheimer's Disease Neuroimaging Initiative
# 258711                               Imaging Genetic Data
# 258712                                         Discussion
# 258713                             Supplementary Material
#
#                                                      text
# 0       There are many assessment tools in social scie...
# 1
# 2       Preparation Stage: In this stage, the research...
# 3       This analysis is used for scale adaptation and...
# 4       By using thematic content analysis (meta-synth...
# ...                                                   ...
# 258709  We first performed a preliminary analysis by u...
# 258710
# 258711  Imaging genetics is an emergent trans-discipli...
# 258712  We have developed a Bayesian analysis GLRR to ...
# 258713  Refer to Web version on PubMed Central for sup...
#
# [258714 rows x 3 columns]

# %%
grouped_dataset_labels = train_labels[['Id','cleaned_label']] \
                                    .groupby('Id') \
                                    .apply(lambda x: list(x['cleaned_label'])) \
                                    .to_frame() \
                                    .reset_index()
grouped_dataset_labels.columns = ['Id', 'cleaned_labels']

# %%
df = grouped_dataset_labels.merge(train_data, left_on='Id', right_on='Id')

# %%
# Out:
#                                           Id  \
# 0       0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 1       0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 2       0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 3       0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 4       0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# ...                                      ...
# 258709  ffeb3568-7aed-4dbe-b177-cbd7f46f34af
# 258710  ffeb3568-7aed-4dbe-b177-cbd7f46f34af
# 258711  ffeb3568-7aed-4dbe-b177-cbd7f46f34af
# 258712  ffeb3568-7aed-4dbe-b177-cbd7f46f34af
# 258713  ffee2676-a778-4521-b947-e1e420b126c5
#
#                                            cleaned_labels  \
# 0       [program for the international assessment of a...
# 1       [program for the international assessment of a...
# 2       [program for the international assessment of a...
# 3       [program for the international assessment of a...
# 4       [program for the international assessment of a...
# ...                                                   ...
# 258709  [trends in international mathematics and scien...
# 258710  [trends in international mathematics and scien...
# 258711  [trends in international mathematics and scien...
# 258712  [trends in international mathematics and scien...
# 258713  [beginning postsecondary student, beginning po...
#
#                                   section_title  \
# 0                                      Abstract
# 1                                  Introduction
# 2                               English and ICT
# 3                                       Lebanon
# 4                  Gender Inequality in Lebanon
# ...                                         ...
# 258709    The role of the status of mathematics
# 258710  Trampoline or self-fulfilling prophecy?
# 258711                                  Summary
# 258712                               Literature
# 258713
#
#                                                      text
# 0       The aim of this study was to identify if acqui...
# 1       The spur of ICT (Information and Communication...
# 2       Studies continue to show that primary language...
# 3       Lebanon is a small country situated in the Mid...
# 4       Lebanese women are in a constant battle with a...
# ...                                                   ...
# 258709  The factor that distinguishes mathematics from...
# 258710  Abandoning mathematics can be a rational strat...
# 258711  The aim of this article was to reconstruct the...
# 258712
# 258713  predicts that tuition and fees at four-year pu...
#
# [258714 rows x 4 columns]

# %%
# cpipe = CorpusPipeline(WORD_DIM, STOP_WORDS)

# %%
cpipe.fit(train_data['text'].to_numpy())

# %%
len(cpipe.word_dict)
# Out:
# 532376

# %%
cpipe.transform(train_data[0:100], 'text')

# %%
' '.join(df['text'].to_numpy())

# %%
cpipe.transform(train[0:10], 'text')
# Out:
# /home/daniel/.conda/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = pd.read_csv('../train.csv')

# %%
# Out:
# "['hello', 'man']"

# %%
json.load(open(WD + train_files[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2cd5d0c76d8e> in <module>
# ----> 1 json.load(open(WD + train_files[0]))
#
# NameError: name 'train_files' is not defined

# %%
pd.read_csv('sample_submission.csv')
# Out:
#                                      Id  PredictionString
# 0  2100032a-7c33-4bff-97ef-690822c43466               NaN
# 1  2f392438-e215-4169-bebf-21ac4ff253e1               NaN
# 2  3f316b38-1a24-45a9-8d8c-4e05a42257c6               NaN
# 3  8e6996b4-ca08-4c0b-bed2-aaf07a4c6a60               NaN

# %%
pd.read_csv('train.csv').sort_values('Id')
# Out:
#                                          Id  \
# 1582   0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 7736   0008656f-0ba2-4632-8602-3017b44c2e90
# 16193  000e04d6-d6ef-442f-b070-4309493221ba
# 4511   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 10461  000efc17-13d8-433d-8f62-a3932fe4f3b8
# ...                                     ...
# 10385  ffd4d86a-0f26-44cc-baed-f0e209cc22af
# 19343  ffe7f334-245a-4de7-b600-d7ff4e28bfca
# 7667   ffeb3568-7aed-4dbe-b177-cbd7f46f34af
# 11079  ffee2676-a778-4521-b947-e1e420b126c5
# 988    ffee2676-a778-4521-b947-e1e420b126c5
#
#                                                pub_title  \
# 1582   The Impact of ICT Training on Income Generatio...
# 7736   Finnish Ninth Graders’ Gender Appropriateness ...
# 16193   Economic Research Service: Specialized Agency...
# 4511   Risk factors and global cognitive status relat...
# 10461  Risk factors and global cognitive status relat...
# ...                                                  ...
# 10385  A Spherical Brain Mapping of MR Images for the...
# 19343  COVID-19 and Possible Pharmacological Preventi...
# 7667   Abandoning mathematics. Reconstructing the pro...
# 11079         A different viewpoint on student retention
# 988           A different viewpoint on student retention
#
#                                            dataset_title  \
# 1582   Program for the International Assessment of Ad...
# 7736   Trends in International Mathematics and Scienc...
# 16193            Agricultural Resource Management Survey
# 4511   Alzheimer's Disease Neuroimaging Initiative (A...
# 10461  Alzheimer's Disease Neuroimaging Initiative (A...
# ...                                                  ...
# 10385  Alzheimer's Disease Neuroimaging Initiative (A...
# 19343                         SARS-CoV-2 genome sequence
# 7667   Trends in International Mathematics and Scienc...
# 11079                    Beginning Postsecondary Student
# 988                      Beginning Postsecondary Student
#
#                                            dataset_label  \
# 1582   Program for the International Assessment of Ad...
# 7736   Trends in International Mathematics and Scienc...
# 16193           Agricultural Resources Management Survey
# 4511                                                ADNI
# 10461  Alzheimer's Disease Neuroimaging Initiative (A...
# ...                                                  ...
# 10385  Alzheimer's Disease Neuroimaging Initiative (A...
# 19343                     genome sequences of SARS-CoV-2
# 7667   Trends in International Mathematics and Scienc...
# 11079                   Beginning Postsecondary Students
# 988                      Beginning Postsecondary Student
#
#                                            cleaned_label
# 1582   program for the international assessment of ad...
# 7736   trends in international mathematics and scienc...
# 16193           agricultural resources management survey
# 4511                                                adni
# 10461  alzheimer s disease neuroimaging initiative adni
# ...                                                  ...
# 10385  alzheimer s disease neuroimaging initiative adni
# 19343                     genome sequences of sars cov 2
# 7667   trends in international mathematics and scienc...
# 11079                   beginning postsecondary students
# 988                      beginning postsecondary student
#
# [19661 rows x 5 columns]
